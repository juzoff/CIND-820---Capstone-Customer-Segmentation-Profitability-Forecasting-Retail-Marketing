# %% [markdown]
# # Importing Stratified Training and Test Set csv Files

# %%
from pandas import read_csv
import pandas as pd

# Specify the encoding as detected ('ascii')
train_data = pd.read_csv('/content/Stratified_train_data.csv', encoding='ascii')  # Updated encoding to 'ascii'

test_data = pd.read_csv('/content/Stratified_test_data.csv', encoding='ascii')  # Updated encoding to 'ascii'

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21000 entries, 0 to 20999
# Data columns (total 86 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer_id                21000 non-null  int64
#  1   age                        21000 non-null  int64
#  2   gender                     21000 non-null  object
#  3   income_bracket             21000 non-null  object
#  4   loyalty_program            21000 non-null  object
#  5   membership_years           21000 non-null  int64
#  6   churned                    21000 non-null  object
#  7   marital_status             21000 non-null  object
#  8   number_of_children         21000 non-null  int64
#  9   education_level            21000 non-null  object
#  10  occupation                 21000 non-null  object
#  11  transaction_id             21000 non-null  int64
#  12  product_id                 21000 non-null  int64
#  13  product_category           21000 non-null  object
#  14  quantity                   21000 non-null  int64
#  15  unit_price                 21000 non-null  float64
#  16  discount_applied           21000 non-null  float64
#  17  payment_method             21000 non-null  object
#  18  store_location             21000 non-null  object
#  19  transaction_hour           21000 non-null  int64
#  20  day_of_week                21000 non-null  object
#  21  week_of_year               21000 non-null  int64
#  22  month_of_year              21000 non-null  int64
#  23  avg_purchase_value         21000 non-null  float64
#  24  purchase_frequency         21000 non-null  object
#  25  avg_discount_used          21000 non-null  float64
#  26  preferred_store            21000 non-null  object
#  27  online_purchases           21000 non-null  int64
#  28  in_store_purchases         21000 non-null  int64
#  29  avg_items_per_transaction  21000 non-null  float64
#  30  avg_transaction_value      21000 non-null  float64
#  31  total_returned_items       21000 non-null  int64
#  32  total_returned_value       21000 non-null  float64
#  33  total_sales_over_lastyear  21000 non-null  float64
#  34  total_transactions         21000 non-null  int64
#  35  total_items_purchased      21000 non-null  int64
#  36  total_discounts_received   21000 non-null  float64
#  37  avg_spent_per_category     21000 non-null  float64
#  38  max_single_purchase_value  21000 non-null  float64
#  39  min_single_purchase_value  21000 non-null  float64
#  40  product_name               21000 non-null  object
#  41  product_brand              21000 non-null  object
#  42  product_rating             21000 non-null  float64
#  43  product_review_count       21000 non-null  int64
#  44  product_stock              21000 non-null  int64
#  45  product_return_rate        21000 non-null  float64
#  46  product_size               21000 non-null  object
#  47  product_weight             21000 non-null  float64
#  48  product_color              21000 non-null  object
#  49  product_material           21000 non-null  object
#  50  product_shelf_life         21000 non-null  int64
#  51  promotion_id               21000 non-null  int64
#  52  promotion_type             21000 non-null  object
#  53  promotion_effectiveness    21000 non-null  object
#  54  promotion_channel          21000 non-null  object
#  55  promotion_target_audience  21000 non-null  object
#  56  customer_zip_code          21000 non-null  int64
#  57  customer_city              21000 non-null  object
#  58  customer_state             21000 non-null  object
#  59  store_zip_code             21000 non-null  int64
#  60  store_city                 21000 non-null  object
#  61  store_state                21000 non-null  object
#  62  distance_to_store          21000 non-null  float64
#  63  holiday_season             21000 non-null  object
#  64  season                     21000 non-null  object
#  65  weekend                    21000 non-null  object
#  66  customer_support_calls     21000 non-null  int64
#  67  email_subscriptions        21000 non-null  object
#  68  app_usage                  21000 non-null  object
#  69  website_visits             21000 non-null  int64
#  70  social_media_engagement    21000 non-null  object
#  71  days_since_last_purchase   21000 non-null  int64
#  72  high_value_purchase        21000 non-null  bool
#  73  high_value_quantity        21000 non-null  bool
#  74  transaction_month          21000 non-null  int64
#  75  transaction_year           21000 non-null  int64
#  76  product_expiry_date_month  21000 non-null  int64
#  77  product_expiry_date_year   21000 non-null  int64
#  78  product_manufacture_month  21000 non-null  int64
#  79  product_manufacture_year   21000 non-null  int64
#  80  promotion_end_month        21000 non-null  int64
#  81  promotion_end_year         21000 non-null  int64
#  82  last_purchase_month        21000 non-null  int64
#  83  last_purchase_year         21000 non-null  int64
#  84  promotion_start_month      21000 non-null  int64
#  85  promotion_start_year       21000 non-null  int64
# dtypes: bool(2), float64(16), int64(36), object(32)
# memory usage: 13.5+ MB

# %% [markdown]
# # RQ1 - Performing K-Means Clustering

# %% [markdown]
# ## Encoding Categorical Attributes, Standardizing Numerical Attributes, Handling Missing Values, PCA, & Finding Optimal Amount of Clusters (Elbow Method & Silhouette Scores)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

# Your existing split (just for clarity here)
# train_data, test_data = train_test_split(sampled_data, test_size=0.3, random_state=42, shuffle=True)

print(f"Training set size: {train_data.shape}")
print(f"Test set size: {test_data.shape}")

# Identify numerical and categorical columns in train data
numerical_cols = train_data.select_dtypes(include=np.number).columns.tolist()
categorical_cols = train_data.select_dtypes(include=['object']).columns.tolist()

# Preprocessing pipeline
preprocessor = ColumnTransformer(transformers=[
    ('num', Pipeline([
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler())
    ]), numerical_cols),

    ('cat', Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]), categorical_cols)
])

# Function to find optimal number of clusters
def find_optimal_k(data, preprocessor, k_range=(2, 11)):
    inertia = []
    silhouette_avg = []
    for k in range(*k_range):
        pipeline = Pipeline([
            ('preprocessor', preprocessor),
            ('pca', PCA(n_components=2)),
            ('kmeans', KMeans(n_clusters=k, random_state=42, n_init=10))
        ])
        labels = pipeline.fit_predict(data)
        pca_data = pipeline.named_steps['pca'].transform(
            pipeline.named_steps['preprocessor'].transform(data)
        )
        inertia.append(pipeline.named_steps['kmeans'].inertia_)
        silhouette_avg.append(silhouette_score(pca_data, labels))
    optimal_k = np.argmax(silhouette_avg) + k_range[0]
    return optimal_k, inertia, silhouette_avg

# Find optimal clusters on training data
optimal_k, inertia, silhouette_avg = find_optimal_k(train_data, preprocessor)
print(f"Optimal number of clusters: {optimal_k}")

# Plot Elbow method
plt.figure(figsize=(10, 5))
plt.plot(range(2, 11), inertia, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# Plot Silhouette scores
plt.figure(figsize=(8, 5))
plt.plot(range(2, 11), silhouette_avg, marker='o')
plt.title('Silhouette Score vs Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.axvline(x=optimal_k, color='r', linestyle='--', label=f'Optimal k = {optimal_k}')
plt.legend()
plt.show()

# Final clustering pipeline with optimal k
clustering_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('pca', PCA(n_components=2)),
    ('kmeans', KMeans(n_clusters=optimal_k, random_state=42, n_init=10))
])

# Fit on train data and assign clusters
train_clusters = clustering_pipeline.fit_predict(train_data)
train_data = train_data.copy()
train_data['cluster'] = train_clusters

# Predict clusters on test data
test_clusters = clustering_pipeline.predict(test_data)
test_data = test_data.copy()
test_data['cluster'] = test_clusters
# Out:
# Training set size: (21000, 86)
# Test set size: (9000, 86)
# Optimal number of clusters: 3

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21000 entries, 0 to 20999
# Data columns (total 87 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer_id                21000 non-null  int64
#  1   age                        21000 non-null  int64
#  2   gender                     21000 non-null  object
#  3   income_bracket             21000 non-null  object
#  4   loyalty_program            21000 non-null  object
#  5   membership_years           21000 non-null  int64
#  6   churned                    21000 non-null  object
#  7   marital_status             21000 non-null  object
#  8   number_of_children         21000 non-null  int64
#  9   education_level            21000 non-null  object
#  10  occupation                 21000 non-null  object
#  11  transaction_id             21000 non-null  int64
#  12  product_id                 21000 non-null  int64
#  13  product_category           21000 non-null  object
#  14  quantity                   21000 non-null  int64
#  15  unit_price                 21000 non-null  float64
#  16  discount_applied           21000 non-null  float64
#  17  payment_method             21000 non-null  object
#  18  store_location             21000 non-null  object
#  19  transaction_hour           21000 non-null  int64
#  20  day_of_week                21000 non-null  object
#  21  week_of_year               21000 non-null  int64
#  22  month_of_year              21000 non-null  int64
#  23  avg_purchase_value         21000 non-null  float64
#  24  purchase_frequency         21000 non-null  object
#  25  avg_discount_used          21000 non-null  float64
#  26  preferred_store            21000 non-null  object
#  27  online_purchases           21000 non-null  int64
#  28  in_store_purchases         21000 non-null  int64
#  29  avg_items_per_transaction  21000 non-null  float64
#  30  avg_transaction_value      21000 non-null  float64
#  31  total_returned_items       21000 non-null  int64
#  32  total_returned_value       21000 non-null  float64
#  33  total_sales_over_lastyear  21000 non-null  float64
#  34  total_transactions         21000 non-null  int64
#  35  total_items_purchased      21000 non-null  int64
#  36  total_discounts_received   21000 non-null  float64
#  37  avg_spent_per_category     21000 non-null  float64
#  38  max_single_purchase_value  21000 non-null  float64
#  39  min_single_purchase_value  21000 non-null  float64
#  40  product_name               21000 non-null  object
#  41  product_brand              21000 non-null  object
#  42  product_rating             21000 non-null  float64
#  43  product_review_count       21000 non-null  int64
#  44  product_stock              21000 non-null  int64
#  45  product_return_rate        21000 non-null  float64
#  46  product_size               21000 non-null  object
#  47  product_weight             21000 non-null  float64
#  48  product_color              21000 non-null  object
#  49  product_material           21000 non-null  object
#  50  product_shelf_life         21000 non-null  int64
#  51  promotion_id               21000 non-null  int64
#  52  promotion_type             21000 non-null  object
#  53  promotion_effectiveness    21000 non-null  object
#  54  promotion_channel          21000 non-null  object
#  55  promotion_target_audience  21000 non-null  object
#  56  customer_zip_code          21000 non-null  int64
#  57  customer_city              21000 non-null  object
#  58  customer_state             21000 non-null  object
#  59  store_zip_code             21000 non-null  int64
#  60  store_city                 21000 non-null  object
#  61  store_state                21000 non-null  object
#  62  distance_to_store          21000 non-null  float64
#  63  holiday_season             21000 non-null  object
#  64  season                     21000 non-null  object
#  65  weekend                    21000 non-null  object
#  66  customer_support_calls     21000 non-null  int64
#  67  email_subscriptions        21000 non-null  object
#  68  app_usage                  21000 non-null  object
#  69  website_visits             21000 non-null  int64
#  70  social_media_engagement    21000 non-null  object
#  71  days_since_last_purchase   21000 non-null  int64
#  72  high_value_purchase        21000 non-null  bool
#  73  high_value_quantity        21000 non-null  bool
#  74  transaction_month          21000 non-null  int64
#  75  transaction_year           21000 non-null  int64
#  76  product_expiry_date_month  21000 non-null  int64
#  77  product_expiry_date_year   21000 non-null  int64
#  78  product_manufacture_month  21000 non-null  int64
#  79  product_manufacture_year   21000 non-null  int64
#  80  promotion_end_month        21000 non-null  int64
#  81  promotion_end_year         21000 non-null  int64
#  82  last_purchase_month        21000 non-null  int64
#  83  last_purchase_year         21000 non-null  int64
#  84  promotion_start_month      21000 non-null  int64
#  85  promotion_start_year       21000 non-null  int64
#  86  cluster                    21000 non-null  int32
# dtypes: bool(2), float64(16), int32(1), int64(36), object(32)
# memory usage: 13.6+ MB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 87 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer_id                9000 non-null   int64
#  1   age                        9000 non-null   int64
#  2   gender                     9000 non-null   object
#  3   income_bracket             9000 non-null   object
#  4   loyalty_program            9000 non-null   object
#  5   membership_years           9000 non-null   int64
#  6   churned                    9000 non-null   object
#  7   marital_status             9000 non-null   object
#  8   number_of_children         9000 non-null   int64
#  9   education_level            9000 non-null   object
#  10  occupation                 9000 non-null   object
#  11  transaction_id             9000 non-null   int64
#  12  product_id                 9000 non-null   int64
#  13  product_category           9000 non-null   object
#  14  quantity                   9000 non-null   int64
#  15  unit_price                 9000 non-null   float64
#  16  discount_applied           9000 non-null   float64
#  17  payment_method             9000 non-null   object
#  18  store_location             9000 non-null   object
#  19  transaction_hour           9000 non-null   int64
#  20  day_of_week                9000 non-null   object
#  21  week_of_year               9000 non-null   int64
#  22  month_of_year              9000 non-null   int64
#  23  avg_purchase_value         9000 non-null   float64
#  24  purchase_frequency         9000 non-null   object
#  25  avg_discount_used          9000 non-null   float64
#  26  preferred_store            9000 non-null   object
#  27  online_purchases           9000 non-null   int64
#  28  in_store_purchases         9000 non-null   int64
#  29  avg_items_per_transaction  9000 non-null   float64
#  30  avg_transaction_value      9000 non-null   float64
#  31  total_returned_items       9000 non-null   int64
#  32  total_returned_value       9000 non-null   float64
#  33  total_sales_over_lastyear  9000 non-null   float64
#  34  total_transactions         9000 non-null   int64
#  35  total_items_purchased      9000 non-null   int64
#  36  total_discounts_received   9000 non-null   float64
#  37  avg_spent_per_category     9000 non-null   float64
#  38  max_single_purchase_value  9000 non-null   float64
#  39  min_single_purchase_value  9000 non-null   float64
#  40  product_name               9000 non-null   object
#  41  product_brand              9000 non-null   object
#  42  product_rating             9000 non-null   float64
#  43  product_review_count       9000 non-null   int64
#  44  product_stock              9000 non-null   int64
#  45  product_return_rate        9000 non-null   float64
#  46  product_size               9000 non-null   object
#  47  product_weight             9000 non-null   float64
#  48  product_color              9000 non-null   object
#  49  product_material           9000 non-null   object
#  50  product_shelf_life         9000 non-null   int64
#  51  promotion_id               9000 non-null   int64
#  52  promotion_type             9000 non-null   object
#  53  promotion_effectiveness    9000 non-null   object
#  54  promotion_channel          9000 non-null   object
#  55  promotion_target_audience  9000 non-null   object
#  56  customer_zip_code          9000 non-null   int64
#  57  customer_city              9000 non-null   object
#  58  customer_state             9000 non-null   object
#  59  store_zip_code             9000 non-null   int64
#  60  store_city                 9000 non-null   object
#  61  store_state                9000 non-null   object
#  62  distance_to_store          9000 non-null   float64
#  63  holiday_season             9000 non-null   object
#  64  season                     9000 non-null   object
#  65  weekend                    9000 non-null   object
#  66  customer_support_calls     9000 non-null   int64
#  67  email_subscriptions        9000 non-null   object
#  68  app_usage                  9000 non-null   object
#  69  website_visits             9000 non-null   int64
#  70  social_media_engagement    9000 non-null   object
#  71  days_since_last_purchase   9000 non-null   int64
#  72  high_value_purchase        9000 non-null   bool
#  73  high_value_quantity        9000 non-null   bool
#  74  transaction_month          9000 non-null   int64
#  75  transaction_year           9000 non-null   int64
#  76  product_expiry_date_month  9000 non-null   int64
#  77  product_expiry_date_year   9000 non-null   int64
#  78  product_manufacture_month  9000 non-null   int64
#  79  product_manufacture_year   9000 non-null   int64
#  80  promotion_end_month        9000 non-null   int64
#  81  promotion_end_year         9000 non-null   int64
#  82  last_purchase_month        9000 non-null   int64
#  83  last_purchase_year         9000 non-null   int64
#  84  promotion_start_month      9000 non-null   int64
#  85  promotion_start_year       9000 non-null   int64
#  86  cluster                    9000 non-null   int32
# dtypes: bool(2), float64(16), int32(1), int64(36), object(32)
# memory usage: 5.8+ MB

# %% [markdown]
# ### Saving Updated Train and Test set files with Cluster Added

# %%
train_data.to_csv('stratstat_train_data.csv', index=False)
test_data.to_csv('stratstat_test_data.csv', index=False)

# %% [markdown]
# ## Visualizing PCA1 & PC2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Step 1: Transform and create PCA DataFrame
X_pca = clustering_pipeline.named_steps['pca'].transform(
    clustering_pipeline.named_steps['preprocessor'].transform(train_data.drop(columns='cluster'))
)
pca_df = pd.DataFrame(X_pca, columns=['PCA1', 'PCA2'])

# Step 2: Convert cluster to categorical with all possible categories
unique_clusters = sorted(train_data['cluster'].unique())
pca_df['cluster'] = pd.Categorical(train_data['cluster'], categories=unique_clusters)

# Step 3: Get KMeans centroids (in PCA space, since PCA comes before KMeans in the pipeline)
centroids = clustering_pipeline.named_steps['kmeans'].cluster_centers_

# Step 4: Plot with all clusters in legend
plt.figure(figsize=(10, 7))
sns.scatterplot(data=pca_df, x='PCA1', y='PCA2', hue='cluster', palette='viridis', alpha=0.7)

plt.scatter(centroids[:, 0], centroids[:, 1], s=250, c='red', marker='X', label='Centroids')

plt.title('Training Set Clusters with PCA')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(title='Cluster', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Analyzing Cluster Characteristics

# %% [markdown]
# ### Top contributors to PC1 & PC2

# %%
# Get the preprocessed feature names
encoded_features = clustering_pipeline.named_steps['preprocessor'].get_feature_names_out()

# Get PCA loadings (components)
loadings = pd.DataFrame(clustering_pipeline.named_steps['pca'].components_.T,
                        columns=['PC1', 'PC2'],
                        index=encoded_features)

# Sort features by absolute contribution to PC1
print("\nTop contributors to PC1:")
print(loadings['PC1'].abs().sort_values(ascending=False).head(50))

# Sort features by absolute contribution to PC2
print("\nTop contributors to PC2:")
print(loadings['PC2'].abs().sort_values(ascending=False).head(50))
# Out:
# Top contributors to PC1:
# num__discount_applied                                 0.327559
# num__product_rating                                   0.320252
# num__avg_transaction_value                            0.287694
# num__avg_spent_per_category                           0.273847
# num__promotion_start_month                            0.259832
# num__total_returned_value                             0.252573
# num__transaction_month                                0.237239
# num__product_review_count                             0.208538
# num__avg_items_per_transaction                        0.208004
# num__total_items_purchased                            0.198563
# num__product_stock                                    0.167004
# num__avg_discount_used                                0.165191
# num__product_expiry_date_year                         0.149832
# num__transaction_year                                 0.148560
# num__product_manufacture_year                         0.144312
# num__days_since_last_purchase                         0.142302
# num__promotion_id                                     0.139397
# num__product_weight                                   0.138165
# num__max_single_purchase_value                        0.135056
# num__unit_price                                       0.134585
# num__transaction_id                                   0.132049
# num__month_of_year                                    0.103658
# num__customer_id                                      0.100817
# num__customer_zip_code                                0.096124
# num__last_purchase_month                              0.094418
# num__quantity                                         0.093032
# num__product_shelf_life                               0.083630
# num__store_zip_code                                   0.065449
# num__avg_purchase_value                               0.058224
# num__product_manufacture_month                        0.055278
# num__product_expiry_date_month                        0.052763
# num__transaction_hour                                 0.052485
# num__product_id                                       0.049399
# num__website_visits                                   0.044470
# num__total_transactions                               0.034222
# num__age                                              0.034016
# num__total_returned_items                             0.033911
# num__number_of_children                               0.028313
# num__membership_years                                 0.028238
# num__customer_support_calls                           0.025261
# num__in_store_purchases                               0.025086
# num__distance_to_store                                0.025084
# num__min_single_purchase_value                        0.024100
# num__week_of_year                                     0.023049
# num__product_return_rate                              0.022387
# num__total_discounts_received                         0.017596
# num__online_purchases                                 0.010168
# cat__marital_status_Married                           0.009828
# cat__promotion_target_audience_Returning Customers    0.009007
# cat__season_Winter                                    0.008663
# Name: PC1, dtype: float64
#
# Top contributors to PC2:
# num__total_returned_items          0.329164
# num__promotion_start_month         0.283681
# num__product_weight                0.263861
# num__min_single_purchase_value     0.251676
# num__distance_to_store             0.242908
# num__max_single_purchase_value     0.219986
# num__customer_id                   0.218687
# num__product_stock                 0.215517
# num__total_sales_over_lastyear     0.215134
# num__product_shelf_life            0.211890
# num__transaction_year              0.198398
# num__customer_zip_code             0.194237
# num__total_returned_value          0.178573
# num__days_since_last_purchase      0.164986
# num__unit_price                    0.162288
# num__product_manufacture_year      0.144028
# num__online_purchases              0.142072
# num__transaction_month             0.141514
# num__product_manufacture_month     0.140886
# num__customer_support_calls        0.129559
# num__product_return_rate           0.118953
# num__transaction_hour              0.116924
# num__avg_transaction_value         0.114500
# num__total_items_purchased         0.096406
# num__discount_applied              0.095925
# num__week_of_year                  0.089322
# num__total_transactions            0.087880
# num__product_expiry_date_year      0.086200
# num__quantity                      0.065404
# num__promotion_id                  0.065181
# num__product_review_count          0.060322
# num__last_purchase_month           0.060244
# num__month_of_year                 0.058143
# num__promotion_end_month           0.058131
# num__website_visits                0.058021
# num__avg_spent_per_category        0.057125
# num__number_of_children            0.053980
# num__membership_years              0.046932
# num__avg_purchase_value            0.036084
# num__product_rating                0.034520
# num__product_id                    0.034453
# num__total_discounts_received      0.031572
# num__transaction_id                0.030851
# num__store_zip_code                0.028420
# num__age                           0.025329
# num__in_store_purchases            0.011155
# cat__purchase_frequency_Yearly     0.011037
# cat__purchase_frequency_Monthly    0.009231
# cat__weekend_Yes                   0.007682
# cat__season_Spring                 0.007522
# Name: PC2, dtype: float64

# %% [markdown]
# #### Visual

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming 'loadings' is the DataFrame from your code
# Create figure with two subplots side by side
plt.figure(figsize=(15, 8))

# Top 20 contributors to PC1
top_pc1 = loadings['PC1'].abs().sort_values(ascending=False).head(20)
plt.subplot(1, 2, 1)
ax1 = sns.barplot(x=top_pc1.values, y=top_pc1.index, palette='Blues_r')
plt.title('Top 20 Contributors to PC1', fontsize=14)
plt.xlabel('Absolute Loading Value', fontsize=12)
plt.ylabel('Feature', fontsize=12)

# Add text annotations for PC1 values
for i, value in enumerate(top_pc1.values):
    ax1.text(value + 0.005, i, f'{value:.3f}', va='center', fontsize=10)

# Top 20 contributors to PC2
top_pc2 = loadings['PC2'].abs().sort_values(ascending=False).head(20)
plt.subplot(1, 2, 2)
ax2 = sns.barplot(x=top_pc2.values, y=top_pc2.index, palette='Oranges_r')
plt.title('Top 20 Contributors to PC2', fontsize=14)
plt.xlabel('Absolute Loading Value', fontsize=12)
plt.ylabel('Feature', fontsize=12)

# Add text annotations for PC2 values
for i, value in enumerate(top_pc2.values):
    ax2.text(value + 0.005, i, f'{value:.3f}', va='center', fontsize=10)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show plot
plt.show()
# Out:
# <ipython-input-9-1978847619>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax1 = sns.barplot(x=top_pc1.values, y=top_pc1.index, palette='Blues_r')
# <ipython-input-9-1978847619>:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax2 = sns.barplot(x=top_pc2.values, y=top_pc2.index, palette='Oranges_r')

# %% [markdown]
# ### Cluster Characteristics (PC1&PC2 Means)

# %%
# Create clustered_data for PCA visualization and analysis
pca_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('pca', PCA(n_components=2))
])
pca_train = pca_pipeline.fit_transform(train_data.drop(columns=['cluster']))
clustered_data = pd.DataFrame(pca_train, columns=['PC1', 'PC2'])
clustered_data['cluster'] = train_data['cluster'].values

# %%
# Display characteristics for each cluster
for cluster_num in sorted(clustered_data['cluster'].unique()):
    print(f"\nCluster {cluster_num} Characteristics:")

    # Get the data for the specific cluster
    cluster_data = clustered_data[clustered_data['cluster'] == cluster_num]

    # Drop the 'cluster' column to focus on features
    cluster_description = cluster_data.drop(columns=['cluster']).describe().T[['mean', '50%']]

    # Display the characteristics for the current cluster
    print(cluster_description)
# Out:
# Cluster 0 Characteristics:
#          mean       50%
# PC1  0.079251  0.054261
# PC2  1.096548  1.009041
#
# Cluster 1 Characteristics:
#          mean       50%
# PC1 -0.974287 -0.867210
# PC2 -0.469247 -0.393152
#
# Cluster 2 Characteristics:
#          mean       50%
# PC1  0.910262  0.793446
# PC2 -0.598392 -0.503854

# %%
# Compute the mean of PC1 and PC2 for each cluster
cluster_pca_means = clustered_data.groupby('cluster')[['PC1', 'PC2']].mean()

print("\nMean PCA Components per Cluster:")
print(cluster_pca_means)
# Out:
# Mean PCA Components per Cluster:
#               PC1       PC2
# cluster
# 0        0.079251  1.096548
# 1       -0.974287 -0.469247
# 2        0.910262 -0.598392

# %% [markdown]
# #### Visual

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming cluster_pca_means is the DataFrame from your code
# Create scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=cluster_pca_means, x='PC1', y='PC2', hue=cluster_pca_means.index,
                size=cluster_pca_means.index, sizes=(100, 400), palette='deep',
                legend='full')
for i, row in cluster_pca_means.iterrows():
    plt.text(row['PC1'] + 0.2, row['PC2'] + 0.2, f'Cluster {i}', fontsize=10)
plt.axhline(0, color='gray', linestyle='--', alpha=0.5)
plt.axvline(0, color='gray', linestyle='--', alpha=0.5)
plt.title('Mean PCA Components per Cluster', fontsize=14)
plt.xlabel('PC1', fontsize=12)
plt.ylabel('PC2', fontsize=12)
plt.legend(title='Cluster')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### PC1 for each individual attribute (mean)

# %%
pd.set_option('display.max_rows', None)
pd.reset_option('display.max_rows')

import pandas as pd

# Set pandas to display numbers in plain float format
pd.set_option('display.float_format', '{:.6f}'.format)

# Optional: reset to default if needed
# pd.reset_option('display.float_format')

import pandas as pd

# Initialize a DataFrame to store the contributions of each attribute for each cluster
cluster_contributions_pc1 = pd.DataFrame(index=loadings.index, columns=cluster_pca_means.index)

# For each cluster, compute the contribution of each attribute using only PC1
for cluster in cluster_pca_means.index:
    # Get the mean PC1 for this cluster
    pc1_mean = cluster_pca_means.loc[cluster, 'PC1']

    # Compute contribution: (PC1_mean * PC1_loading)
    contributions = pc1_mean * loadings['PC1']

    # Store the contributions for this cluster
    cluster_contributions_pc1[cluster] = contributions

# Rename the columns for clarity
cluster_contributions_pc1.columns = [f'Cluster {i}' for i in cluster_contributions_pc1.columns]

print("\nCluster Characteristics (Contributions of Original Attributes, PC1 Only):")
print(cluster_contributions_pc1)
# Out:
# Cluster Characteristics (Contributions of Original Attributes, PC1 Only):
#                                      Cluster 0  Cluster 1  Cluster 2
# num__customer_id                     -0.007990   0.098225  -0.091770
# num__age                             -0.002696   0.033142  -0.030964
# num__membership_years                -0.002238   0.027512  -0.025704
# num__number_of_children               0.002244  -0.027585   0.025772
# num__transaction_id                   0.010465  -0.128653   0.120199
# ...                                        ...        ...        ...
# cat__email_subscriptions_Yes         -0.000199   0.002444  -0.002284
# cat__app_usage_Low                    0.000167  -0.002054   0.001919
# cat__app_usage_Medium                -0.000095   0.001162  -0.001086
# cat__social_media_engagement_Low     -0.000263   0.003232  -0.003020
# cat__social_media_engagement_Medium   0.000238  -0.002928   0.002736
#
# [129 rows x 3 columns]

# %%
pd.set_option('display.max_rows', None)

# Then run your print statement
print(cluster_contributions_pc1)
# Out:
#                                                     Cluster 0  Cluster 1  \
# num__customer_id                                    -0.007990   0.098225
# num__age                                            -0.002696   0.033142
# num__membership_years                               -0.002238   0.027512
# num__number_of_children                              0.002244  -0.027585
# num__transaction_id                                  0.010465  -0.128653
# num__product_id                                     -0.003915   0.048129
# num__quantity                                        0.007373  -0.090640
# num__unit_price                                     -0.010666   0.131124
# num__discount_applied                                0.025959  -0.319137
# num__transaction_hour                               -0.004160   0.051136
# num__week_of_year                                   -0.001827   0.022457
# num__month_of_year                                  -0.008215   0.100992
# num__avg_purchase_value                              0.004614  -0.056727
# num__avg_discount_used                               0.013092  -0.160943
# num__online_purchases                                0.000806  -0.009907
# num__in_store_purchases                              0.001988  -0.024441
# num__avg_items_per_transaction                       0.016485  -0.202655
# num__avg_transaction_value                          -0.022800   0.280297
# num__total_returned_items                           -0.002687   0.033039
# num__total_returned_value                            0.020017  -0.246079
# num__total_sales_over_lastyear                      -0.000444   0.005454
# num__total_transactions                              0.002712  -0.033342
# num__total_items_purchased                          -0.015736   0.193457
# num__total_discounts_received                       -0.001395   0.017144
# num__avg_spent_per_category                          0.021703  -0.266806
# num__max_single_purchase_value                       0.010703  -0.131583
# num__min_single_purchase_value                       0.001910  -0.023480
# num__product_rating                                  0.025380  -0.312017
# num__product_review_count                            0.016527  -0.203176
# num__product_stock                                   0.013235  -0.162710
# num__product_return_rate                            -0.001774   0.021812
# num__product_weight                                 -0.010950   0.134612
# num__product_shelf_life                              0.006628  -0.081479
# num__promotion_id                                    0.011047  -0.135813
# num__customer_zip_code                              -0.007618   0.093652
# num__store_zip_code                                  0.005187  -0.063766
# num__distance_to_store                               0.001988  -0.024439
# num__customer_support_calls                          0.002002  -0.024611
# num__website_visits                                 -0.003524   0.043327
# num__days_since_last_purchase                        0.011278  -0.138643
# num__transaction_month                               0.018801  -0.231139
# num__transaction_year                                0.011774  -0.144740
# num__product_expiry_date_month                      -0.004182   0.051407
# num__product_expiry_date_year                       -0.011874   0.145980
# num__product_manufacture_month                      -0.004381   0.053856
# num__product_manufacture_year                        0.011437  -0.140602
# num__promotion_end_month                            -0.000174   0.002133
# num__promotion_end_year                             -0.000000   0.000000
# num__last_purchase_month                            -0.007483   0.091990
# num__last_purchase_year                             -0.000000   0.000000
# num__promotion_start_month                           0.020592  -0.253151
# num__promotion_start_year                           -0.000000   0.000000
# cat__gender_Male                                    -0.000220   0.002705
# cat__gender_Other                                    0.000626  -0.007701
# cat__income_bracket_Low                             -0.000206   0.002538
# cat__income_bracket_Medium                           0.000318  -0.003912
# cat__loyalty_program_Yes                            -0.000494   0.006072
# cat__churned_Yes                                     0.000301  -0.003696
# cat__marital_status_Married                          0.000779  -0.009575
# cat__marital_status_Single                          -0.000257   0.003157
# cat__education_level_High School                     0.000259  -0.003180
# cat__education_level_Master's                       -0.000306   0.003766
# cat__education_level_PhD                             0.000010  -0.000124
# cat__occupation_Retired                             -0.000406   0.004992
# cat__occupation_Self-Employed                        0.000197  -0.002427
# cat__occupation_Unemployed                           0.000061  -0.000749
# cat__product_category_Electronics                   -0.000125   0.001534
# cat__product_category_Furniture                      0.000307  -0.003777
# cat__product_category_Groceries                      0.000189  -0.002325
# cat__product_category_Toys                           0.000076  -0.000935
# cat__payment_method_Credit Card                     -0.000012   0.000146
# cat__payment_method_Debit Card                       0.000465  -0.005721
# cat__payment_method_Mobile Payment                  -0.000179   0.002204
# cat__store_location_Location B                      -0.000002   0.000029
# cat__store_location_Location C                       0.000349  -0.004289
# cat__store_location_Location D                      -0.000072   0.000879
# cat__day_of_week_Monday                              0.000151  -0.001857
# cat__day_of_week_Saturday                           -0.000194   0.002380
# cat__day_of_week_Sunday                             -0.000051   0.000622
# cat__day_of_week_Thursday                           -0.000053   0.000654
# cat__day_of_week_Tuesday                             0.000257  -0.003155
# cat__day_of_week_Wednesday                          -0.000039   0.000481
# cat__purchase_frequency_Monthly                      0.000068  -0.000832
# cat__purchase_frequency_Weekly                      -0.000274   0.003373
# cat__purchase_frequency_Yearly                       0.000234  -0.002882
# cat__preferred_store_Location B                      0.000043  -0.000524
# cat__preferred_store_Location C                     -0.000034   0.000414
# cat__preferred_store_Location D                      0.000234  -0.002871
# cat__product_name_Product B                         -0.000231   0.002836
# cat__product_name_Product C                         -0.000191   0.002348
# cat__product_name_Product D                         -0.000062   0.000758
# cat__product_brand_Brand Y                          -0.000031   0.000386
# cat__product_brand_Brand Z                           0.000125  -0.001539
# cat__product_size_Medium                             0.000143  -0.001755
# cat__product_size_Small                             -0.000225   0.002765
# cat__product_color_Blue                              0.000102  -0.001254
# cat__product_color_Green                            -0.000198   0.002439
# cat__product_color_Red                               0.000546  -0.006713
# cat__product_color_White                            -0.000516   0.006346
# cat__product_material_Metal                          0.000220  -0.002702
# cat__product_material_Plastic                        0.000130  -0.001598
# cat__product_material_Wood                          -0.000182   0.002237
# cat__promotion_type_Buy One Get One Free            -0.000087   0.001071
# cat__promotion_type_Flash Sale                       0.000032  -0.000388
# cat__promotion_effectiveness_Low                     0.000010  -0.000128
# cat__promotion_effectiveness_Medium                  0.000069  -0.000850
# cat__promotion_channel_Online                        0.000444  -0.005458
# cat__promotion_channel_Social Media                 -0.000459   0.005644
# cat__promotion_target_audience_Returning Customers  -0.000714   0.008775
# cat__customer_city_City B                           -0.000538   0.006618
# cat__customer_city_City C                           -0.000052   0.000638
# cat__customer_city_City D                            0.000155  -0.001905
# cat__customer_state_State Y                          0.000580  -0.007131
# cat__customer_state_State Z                         -0.000333   0.004091
# cat__store_city_City B                               0.000395  -0.004855
# cat__store_city_City C                              -0.000369   0.004536
# cat__store_city_City D                               0.000060  -0.000737
# cat__store_state_State Y                            -0.000161   0.001976
# cat__store_state_State Z                            -0.000029   0.000360
# cat__holiday_season_Yes                             -0.000665   0.008171
# cat__season_Spring                                   0.000102  -0.001251
# cat__season_Summer                                   0.000050  -0.000614
# cat__season_Winter                                  -0.000687   0.008440
# cat__weekend_Yes                                    -0.000152   0.001864
# cat__email_subscriptions_Yes                        -0.000199   0.002444
# cat__app_usage_Low                                   0.000167  -0.002054
# cat__app_usage_Medium                               -0.000095   0.001162
# cat__social_media_engagement_Low                    -0.000263   0.003232
# cat__social_media_engagement_Medium                  0.000238  -0.002928
#
#                                                     Cluster 2
# num__customer_id                                    -0.091770
# num__age                                            -0.030964
# num__membership_years                               -0.025704
# num__number_of_children                              0.025772
# num__transaction_id                                  0.120199
# num__product_id                                     -0.044966
# num__quantity                                        0.084683
# num__unit_price                                     -0.122507
# num__discount_applied                                0.298165
# num__transaction_hour                               -0.047775
# num__week_of_year                                   -0.020981
# num__month_of_year                                  -0.094356
# num__avg_purchase_value                              0.052999
# num__avg_discount_used                               0.150367
# num__online_purchases                                0.009256
# num__in_store_purchases                              0.022835
# num__avg_items_per_transaction                       0.189338
# num__avg_transaction_value                          -0.261877
# num__total_returned_items                           -0.030868
# num__total_returned_value                            0.229908
# num__total_sales_over_lastyear                      -0.005095
# num__total_transactions                              0.031151
# num__total_items_purchased                          -0.180744
# num__total_discounts_received                       -0.016017
# num__avg_spent_per_category                          0.249273
# num__max_single_purchase_value                       0.122936
# num__min_single_purchase_value                       0.021937
# num__product_rating                                  0.291513
# num__product_review_count                            0.189824
# num__product_stock                                   0.152018
# num__product_return_rate                            -0.020378
# num__product_weight                                 -0.125766
# num__product_shelf_life                              0.076125
# num__promotion_id                                    0.126888
# num__customer_zip_code                              -0.087498
# num__store_zip_code                                  0.059576
# num__distance_to_store                               0.022833
# num__customer_support_calls                          0.022994
# num__website_visits                                 -0.040480
# num__days_since_last_purchase                        0.129532
# num__transaction_month                               0.215950
# num__transaction_year                                0.135228
# num__product_expiry_date_month                      -0.048028
# num__product_expiry_date_year                       -0.136387
# num__product_manufacture_month                      -0.050317
# num__product_manufacture_year                        0.131362
# num__promotion_end_month                            -0.001993
# num__promotion_end_year                             -0.000000
# num__last_purchase_month                            -0.085945
# num__last_purchase_year                             -0.000000
# num__promotion_start_month                           0.236515
# num__promotion_start_year                           -0.000000
# cat__gender_Male                                    -0.002527
# cat__gender_Other                                    0.007195
# cat__income_bracket_Low                             -0.002372
# cat__income_bracket_Medium                           0.003655
# cat__loyalty_program_Yes                            -0.005673
# cat__churned_Yes                                     0.003453
# cat__marital_status_Married                          0.008946
# cat__marital_status_Single                          -0.002949
# cat__education_level_High School                     0.002971
# cat__education_level_Master's                       -0.003518
# cat__education_level_PhD                             0.000116
# cat__occupation_Retired                             -0.004664
# cat__occupation_Self-Employed                        0.002268
# cat__occupation_Unemployed                           0.000699
# cat__product_category_Electronics                   -0.001433
# cat__product_category_Furniture                      0.003529
# cat__product_category_Groceries                      0.002172
# cat__product_category_Toys                           0.000874
# cat__payment_method_Credit Card                     -0.000136
# cat__payment_method_Debit Card                       0.005345
# cat__payment_method_Mobile Payment                  -0.002059
# cat__store_location_Location B                      -0.000027
# cat__store_location_Location C                       0.004007
# cat__store_location_Location D                      -0.000821
# cat__day_of_week_Monday                              0.001735
# cat__day_of_week_Saturday                           -0.002224
# cat__day_of_week_Sunday                             -0.000581
# cat__day_of_week_Thursday                           -0.000611
# cat__day_of_week_Tuesday                             0.002948
# cat__day_of_week_Wednesday                          -0.000449
# cat__purchase_frequency_Monthly                      0.000778
# cat__purchase_frequency_Weekly                      -0.003151
# cat__purchase_frequency_Yearly                       0.002692
# cat__preferred_store_Location B                      0.000490
# cat__preferred_store_Location C                     -0.000387
# cat__preferred_store_Location D                      0.002682
# cat__product_name_Product B                         -0.002650
# cat__product_name_Product C                         -0.002193
# cat__product_name_Product D                         -0.000708
# cat__product_brand_Brand Y                          -0.000361
# cat__product_brand_Brand Z                           0.001438
# cat__product_size_Medium                             0.001640
# cat__product_size_Small                             -0.002584
# cat__product_color_Blue                              0.001171
# cat__product_color_Green                            -0.002279
# cat__product_color_Red                               0.006272
# cat__product_color_White                            -0.005929
# cat__product_material_Metal                          0.002525
# cat__product_material_Plastic                        0.001493
# cat__product_material_Wood                          -0.002090
# cat__promotion_type_Buy One Get One Free            -0.001000
# cat__promotion_type_Flash Sale                       0.000363
# cat__promotion_effectiveness_Low                     0.000120
# cat__promotion_effectiveness_Medium                  0.000794
# cat__promotion_channel_Online                        0.005100
# cat__promotion_channel_Social Media                 -0.005273
# cat__promotion_target_audience_Returning Customers  -0.008199
# cat__customer_city_City B                           -0.006183
# cat__customer_city_City C                           -0.000596
# cat__customer_city_City D                            0.001780
# cat__customer_state_State Y                          0.006663
# cat__customer_state_State Z                         -0.003822
# cat__store_city_City B                               0.004536
# cat__store_city_City C                              -0.004238
# cat__store_city_City D                               0.000688
# cat__store_state_State Y                            -0.001846
# cat__store_state_State Z                            -0.000337
# cat__holiday_season_Yes                             -0.007634
# cat__season_Spring                                   0.001168
# cat__season_Summer                                   0.000574
# cat__season_Winter                                  -0.007886
# cat__weekend_Yes                                    -0.001742
# cat__email_subscriptions_Yes                        -0.002284
# cat__app_usage_Low                                   0.001919
# cat__app_usage_Medium                               -0.001086
# cat__social_media_engagement_Low                    -0.003020
# cat__social_media_engagement_Medium                  0.002736

# %% [markdown]
# #### Visual

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming 'cluster_contributions_pc1' and 'loadings' are the DataFrames from your code
# Select top 20 features based on absolute PC1 loadings from earlier data
top_pc1_features = loadings['PC1'].abs().sort_values(ascending=False).head(30).index
top_contributions = cluster_contributions_pc1.loc[top_pc1_features]

# Create heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(top_contributions, annot=True, fmt='.3f', cmap='RdBu_r',
            center=0, cbar_kws={'label': 'PC1 Contribution'})
plt.title('Top 20 Feature Contributions to PC1 by Cluster', fontsize=14)
plt.xlabel('Cluster', fontsize=12)
plt.ylabel('Feature', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### PC2 for each indivudal attribute (mean)

# %%
pd.set_option('display.max_rows', None)
pd.reset_option('display.max_rows')

import pandas as pd

# Set pandas to display numbers in plain float format
pd.set_option('display.float_format', '{:.6f}'.format)

# Optional: reset to default if needed
# pd.reset_option('display.float_format')

import pandas as pd

# Initialize a DataFrame to store the contributions of each attribute for each cluster
cluster_contributions_pc2 = pd.DataFrame(index=loadings.index, columns=cluster_pca_means.index)

# For each cluster, compute the contribution of each attribute using only PC1
for cluster in cluster_pca_means.index:
    # Get the mean PC1 for this cluster
    pc2_mean = cluster_pca_means.loc[cluster, 'PC2']

    # Compute contribution: (PC1_mean * PC1_loading)
    contributions = pc2_mean * loadings['PC2']

    # Store the contributions for this cluster
    cluster_contributions_pc2[cluster] = contributions

# Rename the columns for clarity
cluster_contributions_pc2.columns = [f'Cluster {i}' for i in cluster_contributions_pc2.columns]

print("\nCluster Characteristics (Contributions of Original Attributes, PC2 Only):")
print(cluster_contributions_pc2)
# Out:
# Cluster Characteristics (Contributions of Original Attributes, PC2 Only):
#                                      Cluster 0  Cluster 1  Cluster 2
# num__customer_id                     -0.239801   0.102618   0.130861
# num__age                             -0.027774   0.011886   0.015157
# num__membership_years                 0.051463  -0.022022  -0.028083
# num__number_of_children              -0.059191   0.025330   0.032301
# num__transaction_id                  -0.033829   0.014477   0.018461
# ...                                        ...        ...        ...
# cat__email_subscriptions_Yes         -0.001695   0.000725   0.000925
# cat__app_usage_Low                   -0.003982   0.001704   0.002173
# cat__app_usage_Medium                -0.003743   0.001602   0.002043
# cat__social_media_engagement_Low      0.000620  -0.000265  -0.000338
# cat__social_media_engagement_Medium   0.002423  -0.001037  -0.001322
#
# [129 rows x 3 columns]

# %%
pd.set_option('display.max_rows', None)

# Then run your print statement
print(cluster_contributions_pc2)
# Out:
#                                                     Cluster 0  Cluster 1  \
# num__customer_id                                    -0.239801   0.102618
# num__age                                            -0.027774   0.011886
# num__membership_years                                0.051463  -0.022022
# num__number_of_children                             -0.059191   0.025330
# num__transaction_id                                 -0.033829   0.014477
# num__product_id                                     -0.037779   0.016167
# num__quantity                                       -0.071719   0.030691
# num__unit_price                                     -0.177957   0.076153
# num__discount_applied                               -0.105187   0.045013
# num__transaction_hour                               -0.128213   0.054866
# num__week_of_year                                   -0.097946   0.041914
# num__month_of_year                                   0.063756  -0.027283
# num__avg_purchase_value                              0.039567  -0.016932
# num__avg_discount_used                              -0.006878   0.002943
# num__online_purchases                               -0.155789   0.066667
# num__in_store_purchases                              0.012232  -0.005234
# num__avg_items_per_transaction                       0.008112  -0.003471
# num__avg_transaction_value                           0.125555  -0.053729
# num__total_returned_items                            0.360944  -0.154459
# num__total_returned_value                            0.195814  -0.083795
# num__total_sales_over_lastyear                      -0.235904   0.100951
# num__total_transactions                             -0.096364   0.041237
# num__total_items_purchased                          -0.105714   0.045238
# num__total_discounts_received                       -0.034620   0.014815
# num__avg_spent_per_category                         -0.062641   0.026806
# num__max_single_purchase_value                      -0.241226   0.103228
# num__min_single_purchase_value                       0.275975  -0.118098
# num__product_rating                                 -0.037853   0.016199
# num__product_review_count                           -0.066146   0.028306
# num__product_stock                                  -0.236324   0.101131
# num__product_return_rate                             0.130437  -0.055818
# num__product_weight                                  0.289336  -0.123816
# num__product_shelf_life                              0.232347  -0.099429
# num__promotion_id                                   -0.071474   0.030586
# num__customer_zip_code                               0.212990  -0.091145
# num__store_zip_code                                 -0.031164   0.013336
# num__distance_to_store                               0.266360  -0.113984
# num__customer_support_calls                          0.142067  -0.060795
# num__website_visits                                  0.063623  -0.027226
# num__days_since_last_purchase                       -0.180915   0.077419
# num__transaction_month                               0.155176  -0.066405
# num__transaction_year                                0.217553  -0.093098
# num__product_expiry_date_month                       0.001886  -0.000807
# num__product_expiry_date_year                        0.094523  -0.040449
# num__product_manufacture_month                       0.154488  -0.066110
# num__product_manufacture_year                        0.157934  -0.067585
# num__promotion_end_month                             0.063743  -0.027278
# num__promotion_end_year                              0.000000  -0.000000
# num__last_purchase_month                            -0.066061   0.028270
# num__last_purchase_year                              0.000000  -0.000000
# num__promotion_start_month                           0.311070  -0.133116
# num__promotion_start_year                           -0.000000   0.000000
# cat__gender_Male                                     0.006832  -0.002924
# cat__gender_Other                                   -0.003137   0.001342
# cat__income_bracket_Low                              0.002092  -0.000895
# cat__income_bracket_Medium                          -0.003135   0.001341
# cat__loyalty_program_Yes                             0.006999  -0.002995
# cat__churned_Yes                                    -0.002303   0.000985
# cat__marital_status_Married                          0.005474  -0.002342
# cat__marital_status_Single                           0.002187  -0.000936
# cat__education_level_High School                    -0.002053   0.000879
# cat__education_level_Master's                       -0.007089   0.003034
# cat__education_level_PhD                             0.001091  -0.000467
# cat__occupation_Retired                              0.002803  -0.001199
# cat__occupation_Self-Employed                        0.002227  -0.000953
# cat__occupation_Unemployed                          -0.005192   0.002222
# cat__product_category_Electronics                    0.005087  -0.002177
# cat__product_category_Furniture                      0.001385  -0.000592
# cat__product_category_Groceries                     -0.003416   0.001462
# cat__product_category_Toys                           0.002630  -0.001126
# cat__payment_method_Credit Card                      0.002280  -0.000976
# cat__payment_method_Debit Card                      -0.001729   0.000740
# cat__payment_method_Mobile Payment                  -0.002944   0.001260
# cat__store_location_Location B                       0.004625  -0.001979
# cat__store_location_Location C                      -0.003912   0.001674
# cat__store_location_Location D                      -0.003038   0.001300
# cat__day_of_week_Monday                             -0.000549   0.000235
# cat__day_of_week_Saturday                            0.002423  -0.001037
# cat__day_of_week_Sunday                             -0.001552   0.000664
# cat__day_of_week_Thursday                            0.002124  -0.000909
# cat__day_of_week_Tuesday                             0.000370  -0.000158
# cat__day_of_week_Wednesday                          -0.003089   0.001322
# cat__purchase_frequency_Monthly                      0.010123  -0.004332
# cat__purchase_frequency_Weekly                      -0.000021   0.000009
# cat__purchase_frequency_Yearly                      -0.012103   0.005179
# cat__preferred_store_Location B                      0.001664  -0.000712
# cat__preferred_store_Location C                     -0.002106   0.000901
# cat__preferred_store_Location D                     -0.001143   0.000489
# cat__product_name_Product B                         -0.002128   0.000911
# cat__product_name_Product C                          0.002593  -0.001109
# cat__product_name_Product D                         -0.000750   0.000321
# cat__product_brand_Brand Y                           0.003340  -0.001429
# cat__product_brand_Brand Z                          -0.006751   0.002889
# cat__product_size_Medium                            -0.000366   0.000156
# cat__product_size_Small                             -0.004214   0.001803
# cat__product_color_Blue                              0.002665  -0.001141
# cat__product_color_Green                            -0.000211   0.000090
# cat__product_color_Red                              -0.004691   0.002008
# cat__product_color_White                             0.003695  -0.001581
# cat__product_material_Metal                          0.002517  -0.001077
# cat__product_material_Plastic                        0.004884  -0.002090
# cat__product_material_Wood                          -0.003375   0.001444
# cat__promotion_type_Buy One Get One Free             0.001273  -0.000545
# cat__promotion_type_Flash Sale                       0.003281  -0.001404
# cat__promotion_effectiveness_Low                     0.005012  -0.002145
# cat__promotion_effectiveness_Medium                 -0.000305   0.000131
# cat__promotion_channel_Online                        0.000474  -0.000203
# cat__promotion_channel_Social Media                 -0.004168   0.001783
# cat__promotion_target_audience_Returning Customers   0.008063  -0.003450
# cat__customer_city_City B                           -0.005155   0.002206
# cat__customer_city_City C                            0.003127  -0.001338
# cat__customer_city_City D                           -0.000821   0.000351
# cat__customer_state_State Y                         -0.007026   0.003007
# cat__customer_state_State Z                          0.005617  -0.002404
# cat__store_city_City B                               0.001797  -0.000769
# cat__store_city_City C                              -0.003672   0.001571
# cat__store_city_City D                               0.002673  -0.001144
# cat__store_state_State Y                             0.000589  -0.000252
# cat__store_state_State Z                            -0.002692   0.001152
# cat__holiday_season_Yes                              0.000126  -0.000054
# cat__season_Spring                                  -0.008248   0.003530
# cat__season_Summer                                   0.005108  -0.002186
# cat__season_Winter                                   0.003154  -0.001350
# cat__weekend_Yes                                    -0.008424   0.003605
# cat__email_subscriptions_Yes                        -0.001695   0.000725
# cat__app_usage_Low                                  -0.003982   0.001704
# cat__app_usage_Medium                               -0.003743   0.001602
# cat__social_media_engagement_Low                     0.000620  -0.000265
# cat__social_media_engagement_Medium                  0.002423  -0.001037
#
#                                                     Cluster 2
# num__customer_id                                     0.130861
# num__age                                             0.015157
# num__membership_years                               -0.028083
# num__number_of_children                              0.032301
# num__transaction_id                                  0.018461
# num__product_id                                      0.020616
# num__quantity                                        0.039137
# num__unit_price                                      0.097112
# num__discount_applied                                0.057401
# num__transaction_hour                                0.069966
# num__week_of_year                                    0.053450
# num__month_of_year                                  -0.034792
# num__avg_purchase_value                             -0.021592
# num__avg_discount_used                               0.003754
# num__online_purchases                                0.085015
# num__in_store_purchases                             -0.006675
# num__avg_items_per_transaction                      -0.004427
# num__avg_transaction_value                          -0.068516
# num__total_returned_items                           -0.196969
# num__total_returned_value                           -0.106856
# num__total_sales_over_lastyear                       0.128734
# num__total_transactions                              0.052587
# num__total_items_purchased                           0.057689
# num__total_discounts_received                        0.018892
# num__avg_spent_per_category                          0.034183
# num__max_single_purchase_value                       0.131638
# num__min_single_purchase_value                      -0.150601
# num__product_rating                                  0.020657
# num__product_review_count                            0.036096
# num__product_stock                                   0.128963
# num__product_return_rate                            -0.071180
# num__product_weight                                 -0.157892
# num__product_shelf_life                             -0.126793
# num__promotion_id                                    0.039004
# num__customer_zip_code                              -0.116230
# num__store_zip_code                                  0.017006
# num__distance_to_store                              -0.145354
# num__customer_support_calls                         -0.077527
# num__website_visits                                 -0.034719
# num__days_since_last_purchase                        0.098726
# num__transaction_month                              -0.084681
# num__transaction_year                               -0.118720
# num__product_expiry_date_month                      -0.001029
# num__product_expiry_date_year                       -0.051581
# num__product_manufacture_month                      -0.084305
# num__product_manufacture_year                       -0.086185
# num__promotion_end_month                            -0.034785
# num__promotion_end_year                             -0.000000
# num__last_purchase_month                             0.036050
# num__last_purchase_year                             -0.000000
# num__promotion_start_month                          -0.169752
# num__promotion_start_year                            0.000000
# cat__gender_Male                                    -0.003728
# cat__gender_Other                                    0.001712
# cat__income_bracket_Low                             -0.001142
# cat__income_bracket_Medium                           0.001711
# cat__loyalty_program_Yes                            -0.003819
# cat__churned_Yes                                     0.001257
# cat__marital_status_Married                         -0.002987
# cat__marital_status_Single                          -0.001194
# cat__education_level_High School                     0.001120
# cat__education_level_Master's                        0.003869
# cat__education_level_PhD                            -0.000595
# cat__occupation_Retired                             -0.001529
# cat__occupation_Self-Employed                       -0.001215
# cat__occupation_Unemployed                           0.002833
# cat__product_category_Electronics                   -0.002776
# cat__product_category_Furniture                     -0.000756
# cat__product_category_Groceries                      0.001864
# cat__product_category_Toys                          -0.001435
# cat__payment_method_Credit Card                     -0.001244
# cat__payment_method_Debit Card                       0.000943
# cat__payment_method_Mobile Payment                   0.001607
# cat__store_location_Location B                      -0.002524
# cat__store_location_Location C                       0.002135
# cat__store_location_Location D                       0.001658
# cat__day_of_week_Monday                              0.000300
# cat__day_of_week_Saturday                           -0.001322
# cat__day_of_week_Sunday                              0.000847
# cat__day_of_week_Thursday                           -0.001159
# cat__day_of_week_Tuesday                            -0.000202
# cat__day_of_week_Wednesday                           0.001686
# cat__purchase_frequency_Monthly                     -0.005524
# cat__purchase_frequency_Weekly                       0.000011
# cat__purchase_frequency_Yearly                       0.006605
# cat__preferred_store_Location B                     -0.000908
# cat__preferred_store_Location C                      0.001149
# cat__preferred_store_Location D                      0.000624
# cat__product_name_Product B                          0.001161
# cat__product_name_Product C                         -0.001415
# cat__product_name_Product D                          0.000409
# cat__product_brand_Brand Y                          -0.001823
# cat__product_brand_Brand Z                           0.003684
# cat__product_size_Medium                             0.000200
# cat__product_size_Small                              0.002300
# cat__product_color_Blue                             -0.001455
# cat__product_color_Green                             0.000115
# cat__product_color_Red                               0.002560
# cat__product_color_White                            -0.002017
# cat__product_material_Metal                         -0.001373
# cat__product_material_Plastic                       -0.002665
# cat__product_material_Wood                           0.001842
# cat__promotion_type_Buy One Get One Free            -0.000695
# cat__promotion_type_Flash Sale                      -0.001790
# cat__promotion_effectiveness_Low                    -0.002735
# cat__promotion_effectiveness_Medium                  0.000166
# cat__promotion_channel_Online                       -0.000259
# cat__promotion_channel_Social Media                  0.002274
# cat__promotion_target_audience_Returning Customers  -0.004400
# cat__customer_city_City B                            0.002813
# cat__customer_city_City C                           -0.001706
# cat__customer_city_City D                            0.000448
# cat__customer_state_State Y                          0.003834
# cat__customer_state_State Z                         -0.003065
# cat__store_city_City B                              -0.000980
# cat__store_city_City C                               0.002004
# cat__store_city_City D                              -0.001459
# cat__store_state_State Y                            -0.000322
# cat__store_state_State Z                             0.001469
# cat__holiday_season_Yes                             -0.000069
# cat__season_Spring                                   0.004501
# cat__season_Summer                                  -0.002787
# cat__season_Winter                                  -0.001721
# cat__weekend_Yes                                     0.004597
# cat__email_subscriptions_Yes                         0.000925
# cat__app_usage_Low                                   0.002173
# cat__app_usage_Medium                                0.002043
# cat__social_media_engagement_Low                    -0.000338
# cat__social_media_engagement_Medium                 -0.001322

# %% [markdown]
# #### Visual

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming 'cluster_contributions_pc1' and 'loadings' are the DataFrames from your code
# Select top 20 features based on absolute PC1 loadings from earlier data
top_pc2_features = loadings['PC2'].abs().sort_values(ascending=False).head(30).index
top_contributions2 = cluster_contributions_pc2.loc[top_pc2_features]

# Create heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(top_contributions2, annot=True, fmt='.3f', cmap='RdBu_r',
            center=0, cbar_kws={'label': 'PC2 Contribution'})
plt.title('Top 20 Feature Contributions to PC2 by Cluster', fontsize=14)
plt.xlabel('Cluster', fontsize=12)
plt.ylabel('Feature', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Cluster Characteristics Visual

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Cluster data
clusters = {
    'Moderate Spenders with Low Engagement': [0.808583, -0.723911, 0.397979, 0.042353],
    'Low-Value, Price-Conscious Customers': [-1.060200, 0.482979, -0.521823, -0.055532],
    'High-Value, Strategic Spenders': [5.185055, 2.836978, 2.552048, 0.271587],
    'Promotion-Driven, High-Return Customers': [1.331803, 14.411425, 0.655504, 0.069758]
}
colors = ['blue', 'red', 'green', 'purple']

# Scatter plot
plt.figure(figsize=(10, 6))
for i, (name, (pc1, pc2, sales, discount)) in enumerate(clusters.items()):
    plt.scatter(pc1, pc2, c=colors[i], s=(abs(sales)+0.5)*200, label=name, alpha=0.7)
    plt.annotate(name, (pc1, pc2), xytext=(5, 5), textcoords='offset points', fontsize=10)
plt.xlabel('PC1 (Spending & Transaction Value)', fontsize=12)
plt.ylabel('PC2 (Discount Sensitivity & Returns)', fontsize=12)
plt.title('Cluster Distribution in PC1-PC2 Space', fontsize=14)
plt.axhline(0, color='gray', linestyle='--', alpha=0.5)
plt.axvline(0, color='gray', linestyle='--', alpha=0.5)
plt.grid(True, alpha=0.3)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # RQ2 - Monte Carlo Simulation

# %%
#Total Sales Revenue Formula = total_sales_revenue = ((avg_transaction_value * total_transactions - total_returned_value - total_discounts_received) * (1 - churned))


#Goal: Estimate Total Sales Revenue per Cluster

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import anderson
import seaborn as sns

# Assuming train_data is already loaded
def validate_distributions(cluster_data, cluster_id):
    variables = ['total_transactions', 'avg_transaction_value', 'total_returned_value', 'total_discounts_received']

    plt.figure(figsize=(15, 4))
    for i, var in enumerate(variables, 1):
        # Histogram with KDE
        plt.subplot(1, 4, i)
        sns.histplot(cluster_data[var], kde=True, color='blue', bins=30)
        plt.title(f'{var} - Cluster {cluster_id}')
        plt.xlabel(var)
        plt.ylabel('Frequency')

        # Anderson-Darling test for normality
        result = anderson(cluster_data[var], dist='norm')
        stat = result.statistic
        critical_value = result.critical_values[2]  # Using 5% significance level
        normality_text = f'Anderson-Darling Stat: {stat:.4f}\nCritical Value (5%): {critical_value:.4f}\n'
        normality_text += "Normal" if stat < critical_value else "Not Normal"
        plt.text(0.05, 0.95, normality_text, transform=plt.gca().transAxes,
                 fontsize=10, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.8))

    plt.tight_layout()
    plt.show()

# Example usage within your loop
for cluster_id in train_data['cluster'].unique():
    cluster_data = train_data[train_data['cluster'] == cluster_id]
    if cluster_data.empty:
        print(f"Cluster {cluster_id} has no data, skipping.")
        continue
    validate_distributions(cluster_data, cluster_id)

# %% [markdown]
# ## Normality check

# %%
from scipy.stats import anderson
import pandas as pd

# Assuming cluster_data is a pandas DataFrame for a specific cluster
def check_normality(cluster_data, cluster_id):
    variables = ['total_transactions', 'avg_transaction_value', 'total_returned_value', 'total_discounts_received']

    for var in variables:
        if var not in cluster_data.columns:
            print(f"Variable {var} not found in cluster_data for Cluster {cluster_id}, skipping.")
            continue

        # Perform Anderson-Darling test
        result = anderson(cluster_data[var], dist='norm')
        stat = result.statistic
        critical_value = result.critical_values[2]  # 5% significance level
        print(f"\nAnderson-Darling test for {var} in Cluster {cluster_id}:")
        print(f"Statistic: {stat:.4f}, Critical Value (5%): {critical_value:.4f}")
        if stat > critical_value:
            print(f"{var} is not normally distributed; consider log-normal or gamma.")
        else:
            print(f"{var} appears normally distributed (cannot reject normality).")

# Example usage within your cluster loop
for cluster_id in train_data['cluster'].unique():
    cluster_data = train_data[train_data['cluster'] == cluster_id]
    if cluster_data.empty:
        print(f"Cluster {cluster_id} has no data, skipping.")
        continue
    print(f"\nTesting Normality for Cluster {cluster_id}")
    check_normality(cluster_data, cluster_id)
# Out:
# Testing Normality for Cluster 2
#
# Anderson-Darling test for total_transactions in Cluster 2:
# Statistic: 81.1595, Critical Value (5%): 0.7870
# total_transactions is not normally distributed; consider log-normal or gamma.
#
# Anderson-Darling test for avg_transaction_value in Cluster 2:
# Statistic: 99.4712, Critical Value (5%): 0.7870
# avg_transaction_value is not normally distributed; consider log-normal or gamma.
#
# Anderson-Darling test for total_returned_value in Cluster 2:
# Statistic: 78.8088, Critical Value (5%): 0.7870
# total_returned_value is not normally distributed; consider log-normal or gamma.
#
# Anderson-Darling test for total_discounts_received in Cluster 2:
# Statistic: 72.3035, Critical Value (5%): 0.7870
# total_discounts_received is not normally distributed; consider log-normal or gamma.
#
# Testing Normality for Cluster 0
#
# Anderson-Darling test for total_transactions in Cluster 0:
# Statistic: 77.1822, Critical Value (5%): 0.7870
# total_transactions is not normally distributed; consider log-normal or gamma.
#
# Anderson-Darling test for avg_transaction_value in Cluster 0:
# Statistic: 65.9597, Critical Value (5%): 0.7870
# avg_transaction_value is not normally distributed; consider log-normal or gamma.
#
# Anderson-Darling test for total_returned_value in Cluster 0:
# Statistic: 88.1558, Critical Value (5%): 0.7870
# total_returned_value is not normally distributed; consider log-normal or gamma.
#
# Anderson-Darling test for total_discounts_received in Cluster 0:
# Statistic: 78.7564, Critical Value (5%): 0.7870
# total_discounts_received is not normally distributed; consider log-normal or gamma.
#
# Testing Normality for Cluster 1
#
# Anderson-Darling test for total_transactions in Cluster 1:
# Statistic: 82.2024, Critical Value (5%): 0.7870
# total_transactions is not normally distributed; consider log-normal or gamma.
#
# Anderson-Darling test for avg_transaction_value in Cluster 1:
# Statistic: 87.0629, Critical Value (5%): 0.7870
# avg_transaction_value is not normally distributed; consider log-normal or gamma.
#
# Anderson-Darling test for total_returned_value in Cluster 1:
# Statistic: 94.9097, Critical Value (5%): 0.7870
# total_returned_value is not normally distributed; consider log-normal or gamma.
#
# Anderson-Darling test for total_discounts_received in Cluster 1:
# Statistic: 89.7409, Critical Value (5%): 0.7870
# total_discounts_received is not normally distributed; consider log-normal or gamma.

# %% [markdown]
# ## The one, improve visuals

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy.stats import anderson, multivariate_normal, poisson

# Check train_data and cluster column
if 'train_data' not in globals() or train_data.empty:
    raise ValueError("train_data is not loaded or is empty!")
if 'cluster' not in train_data.columns:
    raise ValueError("Column 'cluster' not found in train_data!")

np.random.seed(42)  # For reproducibility
num_simulations = 100000
sns.set_style("whitegrid")  # Set Seaborn style for better aesthetics
palette = sns.color_palette("viridis", n_colors=len(train_data['cluster'].unique()))  # Consistent color palette

# Initialize lists to store results for cross-cluster visualizations
all_simulated_revenues = []
all_non_churn_revenues = []
churn_sensitivity_results = []

def lognormal_params(mean, std):
    if mean <= 0 or std <= 0:
        raise ValueError("Mean and std must be positive for log-normal.")
    mu = np.log(mean**2 / np.sqrt(std**2 + mean**2))
    sigma = np.sqrt(np.log(1 + (std**2 / mean**2)))
    return mu, sigma

def validate_distributions(cluster_data, cluster_id):
    variables = ['total_transactions', 'avg_transaction_value', 'total_returned_value', 'total_discounts_received']
    print(f"\nTesting Normality for Cluster {cluster_id}")
    for var in variables:
        if var not in cluster_data.columns:
            print(f"Variable {var} not found in cluster_data for Cluster {cluster_id}, skipping.")
            continue
        stat = anderson(cluster_data[var], dist='norm')
        crit_value = stat.critical_values[2]  # 5% significance level
        print(f"Anderson-Darling test for {var} in Cluster {cluster_id}:")
        print(f"Statistic: {stat.statistic:.4f}, Critical Value (5%): {crit_value:.4f}")
        if stat.statistic > crit_value:
            print(f"{var} is not normally distributed; consider log-normal or gamma.")
        else:
            print(f"{var} appears normally distributed.")

for cluster_id in train_data['cluster'].unique():
    cluster_data = train_data[train_data['cluster'] == cluster_id]
    if cluster_data.empty:
        print(f"Cluster {cluster_id} has no data, skipping.")
        continue

    # Validate distributions
    validate_distributions(cluster_data, cluster_id)

    # Compute parameters
    trans_mean = cluster_data['total_transactions'].mean()
    avg_value_mean = cluster_data['avg_transaction_value'].mean()
    avg_value_std = cluster_data['avg_transaction_value'].std()
    avg_value_min = cluster_data['avg_transaction_value'].min()
    return_mean = cluster_data['total_returned_value'].mean()
    return_std = cluster_data['total_returned_value'].std()
    return_min = cluster_data['total_returned_value'].min()
    discount_mean = cluster_data['total_discounts_received'].mean()
    discount_std = cluster_data['total_discounts_received'].std()
    discount_min = cluster_data['total_discounts_received'].min()
    churn_prob = (cluster_data['churned'] == 'Yes').mean()

    print(f"Churn Probability for Cluster {cluster_id}: {churn_prob:.4f}")
    print(f"Average Discount-to-Transaction-Value Ratio (Cluster {cluster_id}): {discount_mean / (avg_value_mean * trans_mean):.4f}")

    # Log-normal parameters for avg_transaction_value, total_returned_value, and total_discounts_received
    avg_value_mu, avg_value_sigma = lognormal_params(avg_value_mean, avg_value_std)
    return_mu, return_sigma = lognormal_params(return_mean, return_std)
    discount_mu, discount_sigma = lognormal_params(discount_mean, discount_std)

    # Compute covariance matrix for log-transformed variables
    log_avg_value = np.log(cluster_data['avg_transaction_value'].clip(avg_value_min))
    log_return = np.log(cluster_data['total_returned_value'].clip(return_min))
    log_discount = np.log(cluster_data['total_discounts_received'].clip(discount_min))
    cov_matrix = pd.DataFrame({
        'log_avg_transaction_value': log_avg_value,
        'log_total_returned_value': log_return,
        'log_total_discounts_received': log_discount
    }).cov().values

    # Simulate correlated log-normal variables
    correlated_vars = multivariate_normal.rvs(
        mean=[avg_value_mu, return_mu, discount_mu],
        cov=cov_matrix,
        size=num_simulations
    )

    # Extract and transform
    avg_value = np.maximum(np.exp(correlated_vars[:, 0]), avg_value_min)
    total_returned_value = np.maximum(np.exp(correlated_vars[:, 1]), return_min)
    total_discounts_received = np.maximum(np.exp(correlated_vars[:, 2]), discount_min)

    # Simulate total_transactions using Poisson
    transactions = poisson.rvs(mu=trans_mean, size=num_simulations)
    transactions = np.maximum(transactions, 1)  # Ensure at least 1 transaction

    # Induce correlation with avg_transaction_value
    corr_target = cluster_data[['total_transactions', 'avg_transaction_value']].corr().iloc[0, 1]
    if abs(corr_target) > 0.1:  # Only adjust if correlation is meaningful
        avg_value_ranks = np.argsort(np.argsort(avg_value))
        transactions_sorted = np.sort(transactions)
        transactions = transactions_sorted[np.argsort(avg_value_ranks)]

    # Simulate churn
    churned = np.random.binomial(n=1, p=churn_prob, size=num_simulations)

    # Calculate total sales revenue
    raw_revenue = (avg_value * transactions - total_returned_value - total_discounts_received)
    negative_revenues = np.sum(raw_revenue < 0)
    print(f"Negative revenue simulations before clipping (Cluster {cluster_id}): {negative_revenues}")
    total_sales_revenue = np.maximum(raw_revenue * (1 - churned), 0)

    # Non-churned revenue analysis
    non_churn_revenue = raw_revenue[churned == 0]  # Use 0 for 'No' churn
    print(f"Mean Revenue for Non-Churned Customers (Cluster {cluster_id}): {np.mean(non_churn_revenue):.2f}")
    print(f"Median Revenue for Non-Churned Customers (Cluster {cluster_id}): {np.median(non_churn_revenue):.2f}")

    # Churn Sensitivity Analysis (10% to 90%)
    print(f"\nChurn Sensitivity Analysis for Cluster {cluster_id}:")
    churn_rates = np.arange(0.1, 1.0, 0.1)  # 10% to 90%
    mean_revenues = []
    for churn_rate in churn_rates:
        churned_scaled = np.random.binomial(n=1, p=churn_rate, size=num_simulations)
        revenue_scaled = np.maximum(raw_revenue * (1 - churned_scaled), 0)
        mean_revenue = np.mean(revenue_scaled)
        mean_revenues.append(mean_revenue)
        print(f"Mean Revenue with Churn Rate {churn_rate:.1f}: {mean_revenue:.2f}")
        churn_sensitivity_results.append({
            'Cluster': cluster_id,
            'Churn_Rate': churn_rate,
            'Mean_Revenue': mean_revenue
        })

    # Store for visualizations
    all_simulated_revenues.append(pd.DataFrame({
        'Revenue': total_sales_revenue,
        'Cluster': f"Cluster {cluster_id}"
    }))
    all_non_churn_revenues.append(pd.DataFrame({
        'Revenue': non_churn_revenue,
        'Cluster': f"Cluster {cluster_id}"
    }))

    # Save results
    results_df = pd.DataFrame({'total_sales_revenue': total_sales_revenue})
    results_df.to_csv(f"cluster_{cluster_id}_revenue_simulation.csv", index=False)

    # Print summary statistics
    print(f"\nTotal Sales Revenue for Cluster {cluster_id} (First 10 Entries):")
    print(total_sales_revenue[:10])
    print(f"Mean of Total Sales Revenue (Cluster {cluster_id}): {np.mean(total_sales_revenue):.2f}")
    print(f"Median of Total Sales Revenue (Cluster {cluster_id}): {np.median(total_sales_revenue):.2f}")
    print(f"5th Percentile: {np.percentile(total_sales_revenue, 5):.2f}")
    print(f"95th Percentile: {np.percentile(total_sales_revenue, 95):.2f}")

# Visualization 1: Enhanced Box Plot of Simulated Revenue Across Clusters (Mean Only)
all_simulated_revenues_df = pd.concat(all_simulated_revenues)
plt.figure(figsize=(12, 6))
box_plot = sns.boxplot(x='Cluster', y='Revenue', data=all_simulated_revenues_df, palette=palette)
sample_size = 100
for cluster in all_simulated_revenues_df['Cluster'].unique():
    cluster_data = all_simulated_revenues_df[all_simulated_revenues_df['Cluster'] == cluster]['Revenue']
    if len(cluster_data) > sample_size:
        sample_data = cluster_data.sample(sample_size, random_state=42)
    else:
        sample_data = cluster_data
    sns.swarmplot(x=[cluster] * len(sample_data), y=sample_data, color='black', size=3, alpha=0.5)
for i, cluster in enumerate(all_simulated_revenues_df['Cluster'].unique()):
    cluster_data = all_simulated_revenues_df[all_simulated_revenues_df['Cluster'] == cluster]['Revenue']
    mean_rev = cluster_data.mean()
    box_plot.text(i, cluster_data.max() + 100, f'Mean: ${mean_rev:.2f}',
                  ha='center', va='bottom', fontsize=10, bbox=dict(facecolor='white', alpha=0.8))
plt.title("Simulated Revenue Distribution Across Clusters with Mean Revenue w/ Original Churn %", fontsize=14)
plt.xlabel("Cluster", fontsize=12)
plt.ylabel("Total Sales Revenue ($)", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# Visualization 2: Bar Plot of Mean Non-Churned Revenue with Confidence Intervals
all_non_churn_revenues_df = pd.concat(all_non_churn_revenues)
non_churn_stats = []
for cluster_id in train_data['cluster'].unique():
    non_churn_data = all_non_churn_revenues_df[all_non_churn_revenues_df['Cluster'] == f"Cluster {cluster_id}"]
    if not non_churn_data.empty:
        mean_rev = non_churn_data['Revenue'].mean()
        std_err = non_churn_data['Revenue'].std() / np.sqrt(len(non_churn_data))
        ci = 1.96 * std_err  # 95% CI
        non_churn_stats.append({
            'Cluster': f"Cluster {cluster_id}",
            'Mean_Revenue': mean_rev,
            'CI_Lower': mean_rev - ci,
            'CI_Upper': mean_rev + ci
        })
non_churn_stats_df = pd.DataFrame(non_churn_stats)
plt.figure(figsize=(12, 6))
bars = sns.barplot(x='Cluster', y='Mean_Revenue', data=non_churn_stats_df, palette=palette, edgecolor='black')
for i, row in non_churn_stats_df.iterrows():
    plt.errorbar(i, row['Mean_Revenue'], yerr=[[row['Mean_Revenue'] - row['CI_Lower']], [row['CI_Upper'] - row['Mean_Revenue']]],
                 fmt='none', c='black', capsize=5)
for bar, mean in zip(bars.patches, non_churn_stats_df['Mean_Revenue']):
    bars.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 50, f'{mean:.2f}',
              ha='center', va='bottom', fontsize=10)
plt.title("Mean Non-Churned Revenue Across Clusters with 95% CI", fontsize=14)
plt.xlabel("Cluster", fontsize=12)
plt.ylabel("Mean Revenue for Non-Churned Customers ($)", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# Visualization 3: Churn Sensitivity Analysis Plot
churn_sensitivity_df = pd.DataFrame(churn_sensitivity_results)
plt.figure(figsize=(12, 6))
for cluster_id in churn_sensitivity_df['Cluster'].unique():
    cluster_data = churn_sensitivity_df[churn_sensitivity_df['Cluster'] == cluster_id]
    plt.plot(cluster_data['Churn_Rate'], cluster_data['Mean_Revenue'], marker='o', label=f"Cluster {cluster_id}", color=palette[cluster_id])
plt.title("Churn Sensitivity Analysis: Mean Revenue vs. Churn Rate", fontsize=14)
plt.xlabel("Churn Rate", fontsize=12)
plt.ylabel("Mean Revenue ($)", fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Testing Normality for Cluster 2
# Anderson-Darling test for total_transactions in Cluster 2:
# Statistic: 81.1595, Critical Value (5%): 0.7870
# total_transactions is not normally distributed; consider log-normal or gamma.
# Anderson-Darling test for avg_transaction_value in Cluster 2:
# Statistic: 99.4712, Critical Value (5%): 0.7870
# avg_transaction_value is not normally distributed; consider log-normal or gamma.
# Anderson-Darling test for total_returned_value in Cluster 2:
# Statistic: 78.8088, Critical Value (5%): 0.7870
# total_returned_value is not normally distributed; consider log-normal or gamma.
# Anderson-Darling test for total_discounts_received in Cluster 2:
# Statistic: 72.3035, Critical Value (5%): 0.7870
# total_discounts_received is not normally distributed; consider log-normal or gamma.
# Churn Probability for Cluster 2: 0.4972
# Average Discount-to-Transaction-Value Ratio (Cluster 2): 0.0463
# Negative revenue simulations before clipping (Cluster 2): 3423
# Mean Revenue for Non-Churned Customers (Cluster 2): 12116.10
# Median Revenue for Non-Churned Customers (Cluster 2): 7632.98
#
# Churn Sensitivity Analysis for Cluster 2:
# Mean Revenue with Churn Rate 0.1: 10881.58
# Mean Revenue with Churn Rate 0.2: 9677.19
# Mean Revenue with Churn Rate 0.3: 8453.05
# Mean Revenue with Churn Rate 0.4: 7267.07
# Mean Revenue with Churn Rate 0.5: 6073.69
# Mean Revenue with Churn Rate 0.6: 4838.18
# Mean Revenue with Churn Rate 0.7: 3594.00
# Mean Revenue with Churn Rate 0.8: 2396.85
# Mean Revenue with Churn Rate 0.9: 1240.24
#
# Total Sales Revenue for Cluster 2 (First 10 Entries):
# [    0.             0.         18506.37247332  8245.10180111
#      0.             0.             0.         32384.63489591
#      0.             0.        ]
# Mean of Total Sales Revenue (Cluster 2): 6106.06
# Median of Total Sales Revenue (Cluster 2): 0.00
# 5th Percentile: 0.00
# 95th Percentile: 27372.18
#
# Testing Normality for Cluster 0
# Anderson-Darling test for total_transactions in Cluster 0:
# Statistic: 77.1822, Critical Value (5%): 0.7870
# total_transactions is not normally distributed; consider log-normal or gamma.
# Anderson-Darling test for avg_transaction_value in Cluster 0:
# Statistic: 65.9597, Critical Value (5%): 0.7870
# avg_transaction_value is not normally distributed; consider log-normal or gamma.
# Anderson-Darling test for total_returned_value in Cluster 0:
# Statistic: 88.1558, Critical Value (5%): 0.7870
# total_returned_value is not normally distributed; consider log-normal or gamma.
# Anderson-Darling test for total_discounts_received in Cluster 0:
# Statistic: 78.7564, Critical Value (5%): 0.7870
# total_discounts_received is not normally distributed; consider log-normal or gamma.
# Churn Probability for Cluster 0: 0.4951
# Average Discount-to-Transaction-Value Ratio (Cluster 0): 0.0387
# Negative revenue simulations before clipping (Cluster 0): 1587
# Mean Revenue for Non-Churned Customers (Cluster 0): 13814.63
# Median Revenue for Non-Churned Customers (Cluster 0): 9718.92
#
# Churn Sensitivity Analysis for Cluster 0:
# Mean Revenue with Churn Rate 0.1: 12476.95
# Mean Revenue with Churn Rate 0.2: 11024.61
# Mean Revenue with Churn Rate 0.3: 9729.17
# Mean Revenue with Churn Rate 0.4: 8314.82
# Mean Revenue with Churn Rate 0.5: 6877.76
# Mean Revenue with Churn Rate 0.6: 5510.85
# Mean Revenue with Churn Rate 0.7: 4179.19
# Mean Revenue with Churn Rate 0.8: 2822.32
# Mean Revenue with Churn Rate 0.9: 1382.74
#
# Total Sales Revenue for Cluster 0 (First 10 Entries):
# [ 2561.98236699     0.          4806.1043151   3406.7870356
#  15981.10834984 11430.05391191 27918.06417352     0.
#  12486.88173853  7617.28425555]
# Mean of Total Sales Revenue (Cluster 0): 7001.12
# Median of Total Sales Revenue (Cluster 0): 0.00
# 5th Percentile: 0.00
# 95th Percentile: 29502.81
#
# Testing Normality for Cluster 1
# Anderson-Darling test for total_transactions in Cluster 1:
# Statistic: 82.2024, Critical Value (5%): 0.7870
# total_transactions is not normally distributed; consider log-normal or gamma.
# Anderson-Darling test for avg_transaction_value in Cluster 1:
# Statistic: 87.0629, Critical Value (5%): 0.7870
# avg_transaction_value is not normally distributed; consider log-normal or gamma.
# Anderson-Darling test for total_returned_value in Cluster 1:
# Statistic: 94.9097, Critical Value (5%): 0.7870
# total_returned_value is not normally distributed; consider log-normal or gamma.
# Anderson-Darling test for total_discounts_received in Cluster 1:
# Statistic: 89.7409, Critical Value (5%): 0.7870
# total_discounts_received is not normally distributed; consider log-normal or gamma.
# Churn Probability for Cluster 1: 0.4864
# Average Discount-to-Transaction-Value Ratio (Cluster 1): 0.0354
# Negative revenue simulations before clipping (Cluster 1): 919
# Mean Revenue for Non-Churned Customers (Cluster 1): 15830.98
# Median Revenue for Non-Churned Customers (Cluster 1): 11625.97
#
# Churn Sensitivity Analysis for Cluster 1:
# Mean Revenue with Churn Rate 0.1: 14237.11
# Mean Revenue with Churn Rate 0.2: 12634.62
# Mean Revenue with Churn Rate 0.3: 11093.22
# Mean Revenue with Churn Rate 0.4: 9500.11
# Mean Revenue with Churn Rate 0.5: 7838.33
# Mean Revenue with Churn Rate 0.6: 6323.38
# Mean Revenue with Churn Rate 0.7: 4740.51
# Mean Revenue with Churn Rate 0.8: 3112.10
# Mean Revenue with Churn Rate 0.9: 1540.20
#
# Total Sales Revenue for Cluster 1 (First 10 Entries):
# [18833.10395826 19921.80573964     0.         18725.29573489
#      0.             0.             0.          4486.56645373
#      0.             0.        ]
# Mean of Total Sales Revenue (Cluster 1): 8195.98
# Median of Total Sales Revenue (Cluster 1): 1692.92
# 5th Percentile: 0.00
# 95th Percentile: 33019.36
# <ipython-input-24-1497635375>:164: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   box_plot = sns.boxplot(x='Cluster', y='Revenue', data=all_simulated_revenues_df, palette=palette)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 7.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 7.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 7.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <ipython-input-24-1497635375>:202: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(x='Cluster', y='Mean_Revenue', data=non_churn_stats_df, palette=palette, edgecolor='black')
